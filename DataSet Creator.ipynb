# %%
import pandas as pd
import os
import shutil

# %%
# Create the data for positive samples

FILE_PATH = "C:\\Users\\Freaky\\Desktop\\chestxray\\metadata.csv"
IMAGE_PATH = "C:\\Users\\Freaky\\Desktop\\chestxray\\images"

# %%
df = pd.read_csv(FILE_PATH)
print(df.shape)
# Out:
# (877, 29)

# %%
df.head()
# Out:
#   patientid  offset sex   age   finding RT_PCR_positive survival intubated  \
# 0         2     0.0   M  65.0  COVID-19               Y        Y         N
# 1         2     3.0   M  65.0  COVID-19               Y        Y         N
# 2         2     5.0   M  65.0  COVID-19               Y        Y         N
# 3         2     6.0   M  65.0  COVID-19               Y        Y         N
# 4         4     0.0   F  52.0  COVID-19               Y      NaN         N
#
#   intubation_present went_icu     ...     modality              date  \
# 0                  N        N     ...        X-ray  January 22, 2020
# 1                  N        N     ...        X-ray  January 25, 2020
# 2                  N        N     ...        X-ray  January 27, 2020
# 3                  N        N     ...        X-ray  January 28, 2020
# 4                  N        N     ...        X-ray  January 25, 2020
#
#                                             location  folder  \
# ...

# %%
# Target directory to store images
TARGET_DIR = "C:\\Users\\Freaky\\Desktop\\Dataset\\Covid"
if not os.path.exists(TARGET_DIR):
    os.mkdir(TARGET_DIR)

# %%
# Place images of covid positive samples in the folder that was created
cnt = 0 

for (i,row) in df.iterrows():
    if row["finding"]=="COVID-19" and row["view"]=="PA":
        filename = row["filename"]
        image_path = os.path.join(IMAGE_PATH,filename)
        image_copy_path = os.path.join(TARGET_DIR,filename)
        shutil.copy2(image_path,image_copy_path)
        print("Moving images",cnt)
         cnt += 1
        
print(cnt)
# Out:
# Moving images 0
# Moving images 1
# Moving images 2
# Moving images 3
# Moving images 4
# Moving images 5
# Moving images 6
# Moving images 7
# Moving images 8
# Moving images 9
# Moving images 10
# Moving images 11
# Moving images 12
# Moving images 13
# Moving images 14
# Moving images 15
# Moving images 16
# Moving images 17
# Moving images 18
# Moving images 19
# Moving images 20
# Moving images 21
# Moving images 22
# Moving images 23
# Moving images 24
# Moving images 25
# Moving images 26
# Moving images 27
# Moving images 28
# Moving images 29
# Moving images 30
# Moving images 31
# Moving images 32
# Moving images 33
# Moving images 34
# Moving images 35
# Moving images 36
# Moving images 37
# Moving images 38
# Moving images 39
# Moving images 40
# Moving images 41
# Moving images 42
# Moving images 43
# Moving images 44
# Moving images 45
# Moving images 46
# Moving images 47
# Moving images 48
# Moving images 49
# Moving images 50
# Moving images 51
# Moving images 52
# ...

# %%
# Sampling of images from Kaggle

import random
KAGGLE_FILE_PATH = "C:\\Users\\Freaky\\Desktop\\chest_xray_kaggle\\chest_xray\\train\\NORMAL"
TARGET_NORMAL_DIR = "C:\\Users\\Freaky\\Desktop\\Dataset\\Normal"

# %%
image_names = os.listdir(KAGGLE_FILE_PATH)

# %%
#Shuffle all 6000 images
random.shuffle(image_names)

# %%
#Take 206 random images from 6000
for i in range(206):
    image_name = image_names[i]
    image_path = os.path.join(KAGGLE_FILE_PATH,image_name)
    target_path = os.path.join(TARGET_NORMAL_DIR,image_name)
    shutil.copy2(image_path,target_path)
    print("copying image ",i)
# Out:
# copying image  0
# copying image  1
# copying image  2
# copying image  3
# copying image  4
# copying image  5
# copying image  6
# copying image  7
# copying image  8
# copying image  9
# copying image  10
# copying image  11
# copying image  12
# copying image  13
# copying image  14
# copying image  15
# copying image  16
# copying image  17
# copying image  18
# copying image  19
# copying image  20
# copying image  21
# copying image  22
# copying image  23
# copying image  24
# copying image  25
# copying image  26
# copying image  27
# copying image  28
# copying image  29
# copying image  30
# copying image  31
# copying image  32
# copying image  33
# copying image  34
# copying image  35
# copying image  36
# copying image  37
# copying image  38
# copying image  39
# copying image  40
# copying image  41
# copying image  42
# copying image  43
# copying image  44
# copying image  45
# copying image  46
# copying image  47
# copying image  48
# copying image  49
# ...
